# %%
# %load_ext autoreload
# %autoreload 2

import os

from dotenv import load_dotenv

from tinygrid import ERCOT, ERCOTAuth, ERCOTAuthConfig

load_dotenv()

auth = ERCOTAuth(ERCOTAuthConfig(
    username=os.getenv("ERCOT_USERNAME"),
    password=os.getenv("ERCOT_PASSWORD"),
    subscription_key=os.getenv("ERCOT_SUBSCRIPTION_KEY"),
))

ercot = ERCOT(auth=auth)

lmp_by_bus = ercot.get_lmp_electrical_bus(
    electrical_bus="ADICKS_345B",
    sced_timestamp_from="2025-12-25T08:15:00",
    sced_timestamp_to="2025-12-25T09:55:00",
    size=2000,
    page=1,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
lmp_by_bus
# Out:
# {'_links': {'self': {'href': 'https://api.ercot.com/api/public-reports/np6-787-cd/lmp_electrical_bus'},
#   'parent': {'href': 'https://api.ercot.com/api/public-reports/np6-787-cd'}},
#  '_meta': {'totalRecords': 20,
#   'pageSize': 2000,
#   'totalPages': 1,
#   'currentPage': 1,
#   'query': {'parameterCount': 3,
#    'parameters': {'SCEDTimestampFrom': {'value': '2025-12-25T08:15:00'},
#     'SCEDTimestampTo': {'value': '2025-12-25T09:55:00'},
#     'electricalBus': {'value': 'ADICKS_345B'}},
#    'sortedBy': 'SCEDTimestamp: DESC'}},
#  'report': {'downloadLimit': 2000000,
#   'reportName': 'lmp_electrical_bus',
#   'reportDisplayName': 'LMP by Electrical Bus',
#   'reportId': '11485',
#   'reportEMIL': 'NP6-787-CD'},
#  'fields': [{'name': 'SCEDTimestamp',
#    'label': 'SCED Time Stamp',
#    'cardinality': 1,
#    'dataType': 'DATETIME',
#    'searchable': True,
#    'sortable': True,
#    'hasRange': True},
#   {'name': 'repeatHourFlag',
#    'label': 'Repeat Hour Flag',
#    'cardinality': 2,
#    'dataType': 'BOOLEAN',
#    'searchable': True,
#    'sortable': True,
#    'hasRange': False},
#   {'name': 'electricalBus',
#    'label': 'Electrical Bus',
#    'cardinality': 3,
#    'dataType': 'VARCHAR',
#    'searchable': True,
#    'sortable': True,
#    'hasRange': False},
#   {'name': 'LMP',
#    'label': 'LMP',
#    'cardinality': 4,
#    'dataType': 'DOUBLE',
#    'searchable': True,
#    'sortable': True,
#    'hasRange': True}],
#  'data': {'records': [['2025-12-25T09:50:14', False, 'ADICKS_345B', 16.57],
#    ['2025-12-25T09:45:15', False, 'ADICKS_345B', 16.75],
#    ['2025-12-25T09:40:15', False, 'ADICKS_345B', 17.06],
#    ['2025-12-25T09:35:14', False, 'ADICKS_345B', 16.97],
#    ['2025-12-25T09:30:14', False, 'ADICKS_345B', 16.91],
#    ['2025-12-25T09:25:14', False, 'ADICKS_345B', 16.81],
#    ['2025-12-25T09:20:14', False, 'ADICKS_345B', 17.08],
#    ['2025-12-25T09:15:15', False, 'ADICKS_345B', 17.34],
#    ['2025-12-25T09:10:15', False, 'ADICKS_345B', 17.07],
#    ['2025-12-25T09:05:16', False, 'ADICKS_345B', 16.2],
#    ['2025-12-25T09:00:18', False, 'ADICKS_345B', 16.17],
#    ['2025-12-25T08:55:15', False, 'ADICKS_345B', 16.16],
#    ['2025-12-25T08:50:14', False, 'ADICKS_345B', 16.05],
#    ['2025-12-25T08:45:14', False, 'ADICKS_345B', 15.58],
#    ['2025-12-25T08:40:15', False, 'ADICKS_345B', 16.28],
#    ['2025-12-25T08:35:15', False, 'ADICKS_345B', 16.82],
#    ['2025-12-25T08:30:14', False, 'ADICKS_345B', 17.86],
#    ['2025-12-25T08:25:15', False, 'ADICKS_345B', 18.06],
#    ['2025-12-25T08:20:15', False, 'ADICKS_345B', 18.08],
#    ['2025-12-25T08:15:14', False, 'ADICKS_345B', 18.53]]}}
